# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Analytics Internship/Week 8/Raw Data/data/heartrate_seconds_merged.csv")
df.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
df.isna().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df['Value'] = df['Value'].apply(lambda x: max(x, 0))

# %%
df.head()
# Out:
#            Id                Time  Value
# 0  2022484408 2016-04-12 07:21:00     97
# 1  2022484408 2016-04-12 07:21:05    102
# 2  2022484408 2016-04-12 07:21:10    105
# 3  2022484408 2016-04-12 07:21:20    103
# 4  2022484408 2016-04-12 07:21:25    101

# %%
df.to_csv('heart_rate_data.csv', index=False)
