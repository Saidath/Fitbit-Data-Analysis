# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Data Analytics Internship/Week 8/Raw Data/data/minuteSleep_merged.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Data Analytics Internship/Week 8/Raw Data/data/sleepDay_merged.csv')

# %%
df = pd.merge(df1, df2, on='Id',how='inner')

# %%
df.head()
# Out:
#            Id                  date  value        logId  \
# 0  1503960366  4/12/2016 2:47:30 AM      3  11380564589
# 1  1503960366  4/12/2016 2:47:30 AM      3  11380564589
# 2  1503960366  4/12/2016 2:47:30 AM      3  11380564589
# 3  1503960366  4/12/2016 2:47:30 AM      3  11380564589
# 4  1503960366  4/12/2016 2:47:30 AM      3  11380564589
#
#                 SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  4/12/2016 12:00:00 AM                  1                 327
# 1  4/13/2016 12:00:00 AM                  2                 384
# 2  4/15/2016 12:00:00 AM                  1                 412
# 3  4/16/2016 12:00:00 AM                  2                 340
# 4  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
df.isna().sum()
# Out:
# Id                    0
# date                  0
# value                 0
# logId                 0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 51834

# %%
df.drop_duplicates(inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y %I:%M:%S %p')
df['SleepDay'] = pd.to_datetime(df['SleepDay'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4650390 entries, 0 to 4702223
# Data columns (total 8 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   date                datetime64[ns]
#  2   value               int64
#  3   logId               int64
#  4   SleepDay            datetime64[ns]
#  5   TotalSleepRecords   int64
#  6   TotalMinutesAsleep  int64
#  7   TotalTimeInBed      int64
# dtypes: datetime64[ns](2), int64(6)
# memory usage: 319.3 MB

# %%
df.head()
# Out:
#            Id                date  value        logId   SleepDay  \
# 0  1503960366 2016-04-12 02:47:30      3  11380564589 2016-04-12
# 1  1503960366 2016-04-12 02:47:30      3  11380564589 2016-04-13
# 2  1503960366 2016-04-12 02:47:30      3  11380564589 2016-04-15
# 3  1503960366 2016-04-12 02:47:30      3  11380564589 2016-04-16
# 4  1503960366 2016-04-12 02:47:30      3  11380564589 2016-04-17
#
#    TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# 0                  1                 327             346
# 1                  2                 384             407
# 2                  1                 412             442
# 3                  2                 340             367
# 4                  1                 700             712

# %%
df.to_csv('/content/drive/MyDrive/Data Analytics Internship/Week 8/Cleaned/SleepDataMerged.csv', index=False)
